# %% [markdown]
# # Business Proposal

# %% [markdown]
# <hr>
#
# # Facilites around Primary Airports in Pakistan
#
# <hr>

# %% [markdown]
# ## INTRODUCTION
#
# Pakistan has long faced a tide of terrorism and a loss of billions of dollars in tourism industry. People around the globe had been reluctant to visit Pakistan due to their pre-imposed idea about the country and its people. But in recent years, this attitude is being shifting towards positive, thanks to the travellogues written by local and foreign tourists.
#
# This positive shift is a welcoming one, by the people of Pakistan and the Government, which is trying its best to show the warm and sunny side of the country that has been long murking in the dark, in the eyes of the world. It is not a surprise now, that the Pakistani tourism industry is on the rise and more and more tourists and businessmen are coming to Pakistan for liesure and busieness purposes.
#
# In this regard, one of the main focus from the Government and people should be to increase the facilities for the incoming foreign and local tourists, so that local businesses may cash-in this opportunity.
#
# It has been observed by some of the tourists, especially the foriegners, who are not accustomed to the local areas, that they sometimes find it hard to locate local leisure and dining facilities due to the lack of proper travelling mobile apps.

# %% [markdown]
# ### Overview of the Problem
#
# Most of the tourists coming from foriegn countries often opt to stay in hotels near the airport. Because of the adventurous and freecaring nature of tourists, they mostly want to visit the city by themsleves without much guidance from any local guide. All tourists coming to Pakistan should have the opportunity to roam and visit the city freely without much intervention from locals, which is guaranteed to give them a sense of freedom and adventure.
#
# Using google maps or apple maps does not provide much independence in this regards, as it only shows the map of the city without categorizing the venues that might be useful to the tourist.
#
# In this project, I am using Foursquare to provide an overview of an app, that could be used by the tourists who come through major/primary international Airports in Pakistan, to have that sense of adventure and freedom.
#
# I will be using foursquare to locate venues near the Airports, categorizing them, so that it is close enough to walk freely from airport  or airport hotel.

# %% [markdown]
# ### Who should be interested
#
# This is a business problem that should be concerning the Tourism Ministry, city governments and businesses in Pakistan. It is a provision of an exciting opportunity to invest in tourism industry, by facilitating the tourists which results in the goodwill of the country and city.

# %% [markdown]
# # DATA

# %% [markdown]
# ## Introduction
#
# In order to make counter this problem, a data set needs to be created, containing the locations of all the venues within a close proximity of the airports that could be detailed on the city map. This will provide a visual framework of the distance and proximity of the facility from the airport.
#
# The data is collected for the primary international airports in Pakistan, namely, Jinnah International Airport, Allama Iqbal International Airport and Islamabad International Airport.
#
# These airports are in the three most advanced and culturural cities in Pakistan, named <b>Karachi</b>, Lahore and Islamabad respectively.

# %% [markdown]
# ### Details of Data
#
# The data collected from Foursquare is very useful in this regrads. The data lists famous spots around a pre-defined area to the Airport, with dedicated properties to each spot containing its location (latitude and longitude), a unique id, name and category, image of the spot, popular item and many more. This data can utilized in so many ways to increase interest to check out these spots.
#
# The properties used in this project are name, categories, latitude and longitude. Other properties can be added to make it more flexible or useful according to the need.

# %% [markdown]
# Let's look at the data in more details. In the below chart, you will find some venues close to the Karachi International Airport, along with their categories, name and locations. This chart can be used to visualize it on a map of Karachi which could be used by tourists to locate nearby spots for leisure facilities.

# %% [markdown]
# <p>
#
# <hr>
#
# |Id |name                                       |categories             |lat          |lng    |
# |---|-------------------------------------------|-----------------------|-------------|-------|
# |0	|Ramada Plaza Hotel Pool BBQ	            |BBQ Joint	            |24.894331	|67.156555|
# |1	|14th Street Pizza	                        |Pizza Place	        |24.910596	|67.096607|
# |2	|California Pizza	                        |Pizza Place	        |24.907824	|67.109657|
# |3	|Pizza Max	                                |Pizza Place	        |24.905053	|67.182587|
# |4	|Butler's Chocolate Cafe	                |Coffee Shop	        |24.901609	|67.166128|
# |5	|GreenO Juice Bar	                        |Juice Bar	            |24.900660	|67.116734|
# |6	|Pakistan Air Force (PAF) Museum	        |History Museum	        |24.869072	|67.094364|
# |7	|Continental Bakery	                        |Bakery	                |24.918897	|67.118315|
# |8	|Luckyone Mall	                            |Shopping Mall	        |24.932513	|67.086961|
# |9	|Aga Khan Sports & Rehabilitation Center	|Gym / Fitness Center	|24.892157	|67.079419|
# |10	|Tutti Frutti	                            |Frozen Yogurt Shop	    |24.874902	|67.088258|
#
# <hr>
#
# <p>

# %% [markdown]
# This is not the complete list to venues, but it could be expanded or shortened according to the need. The number of venues according to their categories can be visualised by a bar chart like below.

# %%
count_khi.reset_index(inplace=True)

count_khi = count_khi[['categories', 'name']]
count_khi = count_khi.rename(columns={'name': 'count'})
count_khi.set_index('categories', inplace=True)
count_khi.plot(kind='bar', figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='categories'>

# %% [markdown]
# You can see that there are alot of variations and options to go around for the tourists interested in roaming the city freely and getting local experiences within a close area of the airport. It can also be seen that the Fast Food Restaurants, Pizza Place, Bakery and Pakistani Restaurants are in high number and these places could be highlighted according to the interest of the tourists.
#
# For example, tourists coming from Western countries migth be more intersted in Pakistani quisine than Fast food, so, pakistani Restaurants can be highlighted for them. Similarly, if they are interested in shopping, Deprtmental Mall & Shopping Malls can be highlighted.
#
# The number of each type of venue/spots are listed in the following table.

# %%
#count_khi2 = count_khi.transpose()
count_khi2
# Out:
# categories  Airport Terminal  Asian Restaurant  Auto Dealership  BBQ Joint  \
# count                      1                 2                1          6
#
# categories  Bakery  Beach  Bistro  Bowling Alley  Burger Joint  Café  \
# count            9      1       1              1             5     5
#
# categories  Coffee Shop  Convenience Store  Cricket Ground  Deli / Bodega  \
# count                 1                  1               1              1
#
# categories  Department Store  Dessert Shop  Diner  Donut Shop  \
# count                      4             2      1           2
#
# categories  Fast Food Restaurant  Fried Chicken Joint  Frozen Yogurt Shop  \
# count                         12                    1                   1
#
# categories  Furniture / Home Store  Golf Course  Gym  Gym / Fitness Center  \
# count                            1            1    1                     1
#
# categories  History Museum  Hookah Bar  Hotel  Ice Cream Shop  \
# ...

# %% [markdown]
# Similar charts are produced for Lahore and Islamabad airports which are shown below,

# %% [markdown]
# Lahore

# %%
count_lhr.reset_index(inplace=True)

count_lhr = count_lhr[['categories', 'name']]
count_lhr = count_lhr.rename(columns={'name': 'count'})
count_lhr.set_index('categories', inplace=True)
count_lhr.plot(kind='bar', figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='categories'>

# %%
count_lhr2 = count_lhr.transpose()
count_lhr2
# Out:
# categories  American Restaurant  Bookstore  Boutique  Burger Joint  Café  \
# count                         2          2         1             2     7
#
# categories  Chinese Restaurant  Coffee Shop  Deli / Bodega  Department Store  \
# count                        3            2              1                 2
#
# categories  Dessert Shop  Fast Food Restaurant  Frozen Yogurt Shop  \
# count                  1                     2                   1
#
# categories  Golf Course  Gym / Fitness Center  Ice Cream Shop  \
# count                 2                     1               3
#
# categories  Italian Restaurant  Juice Bar  Lebanese Restaurant  Market  \
# count                        2          1                    1       1
#
# categories  Middle Eastern Restaurant  Movie Theater  Pakistani Restaurant  \
# count                               1              1                     2
#
# categories  Portuguese Restaurant  Restaurant  Salon / Barbershop  \
# ...

# %% [markdown]
# And Islamabad

# %%
count_isb.reset_index(inplace=True)

count_isb = count_isb[['categories', 'name']]
count_isb = count_isb.rename(columns={'name': 'count'})
count_isb.set_index('categories', inplace=True)
count_isb.plot(kind='bar', figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='categories'>

# %%
count_isb2 = count_isb.transpose()
count_isb2
# Out:
# categories  Asian Restaurant  BBQ Joint  Bakery  Boutique  Burger Joint  Café  \
# count                      2          2       7         1             2     3
#
# categories  Coffee Shop  Department Store  Fast Food Restaurant  Flea Market  \
# count                 3                 1                     1            1
#
# categories  Food Court  Golf Course  Gym  History Museum  Hotel  \
# count                1            2    1               2      2
#
# categories  Ice Cream Shop  Lake  Market  Multiplex  Other Great Outdoors  \
# count                    2     1       3          1                     1
#
# categories  Pakistani Restaurant  Park  Pharmacy  Pizza Place  Sandwich Place  \
# count                          4     1         2            1               1
#
# categories  Shopping Mall  Snack Place  Tea Room  Trail  Wings Joint
# count                   2            1         1      1            1

# %% [markdown]
# ## Summary

# %% [markdown]
# The data colected from Foursquare is very flexible in its application. As shown in the above graphs and charts, it can be used to map over the city with locations, names, categories, which can be very helpful to the tourists coming to these cities.
#
# As can be shown, it can also be expandeed to other cities as well, which are famous for tourism like in northern areas. But it is beyond the scope of this project.

# %% [markdown]
# # METHODOLOGY

# %% [markdown]
# In this section, I will detail the methodology used to collect the data and map onto the cities.
#
# The main part of this project is to collect the data for the venues in the aforementioned cities airports. The data is collected through Foursquare, which is one of the best databases for developers, used across the world for its simplicity and details in data collection and representation. The data stored in the Foursquare databases include names and categories of venues in cities, their locations, images, main items that the venue is famous for, customer ratings and comments. Database also include customers data, which could be used to identify the customer interests and likenesses. Each spot and customer is given a unique id that could be used by the developers to identify each customer and venue.
#
# For this project, the data collected had name, categories and its locations for the venues in close proximity to the international airports in the three cities of Karachi, Lahore and Islamabad. The data was collected throug using the unique developer client id and password id, which could be used to call 1500 calls per day through the Foursquare database.
#
# At first the geo-location of the cities was collected using geolocator function in the geopy package in python. This package has some exciting features including geolocation of cities and towns across the globe. The Function geolocator was used recall the latitudes and longitudes of Karachi, Lahore and Islamabad, and centered around the citys' International airports, namely Jinnah International, Allama Iqbal International and Islamabad International Airport.
#
# This location for the citys' airports was then used to find the venues and spots close to the airports by calling from Foursquare database and storing in pandas dataframe. Each of these dataframe was cleaned and wrangled to refine it as required. The resulting dataframes included venue name, category, latitude and longitude as shown in one of the tables above.

# %% [markdown]
# The categories of the venues and their count varies for each city, which are also showed in the bar plots and tables above.

# %% [markdown]
# The next step was to create the might highlighting these venues in the cities. Folium package was used for this purpose. Folium package is one of the most widely used package for the rendering of interactive maps and images on python. The location of citys' airports extracted from Foursquare database was used to create map through Folium and identify the airport with a red circle. Then, the databases for venues of each city are used to impose the venues on the same city map with blue dots highlighting the venues while airport as red circle. This is done to give a visual approximation of the distance between the airport and the venue.

# %% [markdown]
# # RESULT

# %% [markdown]
# The following image shows the map of Karachi with venues around its International Airport.

# %%
khi_venues_map = folium.Map(location=[khi_latitude, khi_longitude], zoom_start=13) # generate map centred around the Airport

# add a red circle marker to represent the 
folium.CircleMarker(
    [khi_latitude, khi_longitude],
    radius=10,
    color='red',
    popup='Karachi International Airport',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(khi_venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(khi_nearby_venues.lat, khi_nearby_venues.lng, khi_nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(khi_venues_map)

# display map
khi_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It can be seen that the Jinnah International Airport is identified as red circle while the venues around it identified as red. The Folium provides the advantage of interactive images which means that you can change and interact with the maps. If you click on any of the highlighted venues, it show the category of the venue. The map can also be zoomed in or out according to the need.

# %% [markdown]
# Below you can find similar maps for Lahore and Islamabad cities.

# %% [markdown]
# Lahore city with Allama Iqbal International Airport

# %%
lhr_venues_map = folium.Map(location=[lhr_latitude, lhr_longitude], zoom_start=12) # generate map centred around the Airport

# add a red circle marker to represent the 
folium.CircleMarker(
    [31.5230777, 74.4034256,],
    radius=10,
    color='red',
    popup='Allama Iqbal International Airport',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(lhr_venues_map)

# add the blue circle markers
for lat, lng, label in zip(lhr_nearby_venues.lat, lhr_nearby_venues.lng, lhr_nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(lhr_venues_map)

# display map
lhr_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Islamabad city with Islamabad International Airport

# %%
isb_venues_map = folium.Map(location=[isb_latitude, isb_longitude], zoom_start=14) # generate map centred around the Airport

# add a red circle marker to represent the 
folium.CircleMarker(
    [isb_latitude, isb_longitude],
    radius=10,
    color='red',
    popup='Islamabad International Airport',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(isb_venues_map)

# add the  blue circle markers
for lat, lng, label in zip(isb_nearby_venues.lat, isb_nearby_venues.lng, isb_nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(isb_venues_map)

# display map
isb_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr>
# In case the maps are not rendering in the github, you can find the images below as non-interactive maps images for Karachi, Lahore and Islamabad respectively.
# <hr>

# %%
import matplotlib.pyplot as plt
# read the image in 
photo=plt.imread("k10.PNG")
plt.imshow(photo)

# %%
photo_lhr=plt.imread("l2.PNG")
plt.imshow(photo_lhr)

# %%
photo_lhr=plt.imread("i2.PNG")
plt.imshow(photo_lhr)

# %% [markdown]
# <hr>

# %% [markdown]
# # DISCUSSION

# %% [markdown]
# In the maps shown above and the charts earlier, it can be show that there are some commonalities and some differences among the three airports and their surroundings. First of all, among the commonalities, it can be seen that the most close venues for each airport has category related to cuisine. It is not very surprising as food restaurants and dining hotels are the most profitable businesses in these megacities. It is also not surprising that other venues like gym/sports activities, cafe's and clubs, and shopping and cinema halls are also very close to the airports. It shows that the cities are vibrant and full of fun activities that can be very interesting for tourists visiting the cities.
#
# Among differences, it can be seen that the venues around Karachi airport are spread all around it while in Lahore and Islamabad airports, the venues are much on one side of the airports. This is due to the fact that teh Karachi Airport is one of the oldest airports in the sub-continental region which was initially built right outside the city limits but the over the years, city has expanded beyond the airport and it now sits almost in the middle of the city.
#
# Airports in Lahore and Islamabad are relatively new and are right outside the city. which is why most of the venues are on one side of the airport. For Lahore, the main city and its venues are west to the airport while for Islamabad, the venues are to the east direction of the airport.
#
# This provides a unique look at the cities and ease of going to these venues for the tourists. In Karachi, the tourist can go any direction of the airport and will be easy to find food restaurants and hotels. While tourists in Lahore and Islamabad airports, would have to travel a little farther to arrive to their desired location.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Looking at the observations in the Discussion section, it can be concluded that Lahore and Islamabad has more opportunities to grow businesses around their hotels as they are not as much concentrated as in Karachi. This provides business opportunities for entrepreuners and tourism ministry to increase the facilities around lahore and Islamabad airports, which can be utilized by tourists to get a local experience. It could be veery beneficial for incoming foreigners who are on a business trip or on a tight schedule, to have these facilities in close proximity to the airport. It can no doubt increase the experience of the tourists and goodwill for the tourism industry in Pakistan.

# %% [markdown]
# <hr>

# %% [markdown]
# This report/Business propsal is prepared by Syed Faizan Ahmed as a project for the Data Science Professional Certifiation.
